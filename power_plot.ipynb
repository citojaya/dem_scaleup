# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os.path

# %matplotlib inline


def readCSV(fin):
#     data = pd.read_csv(fin, sep=" ", header=None, skiprows=[0,1,2])
    data = pd.read_csv(fin)
    return data


def readFile(fin):
    time = []
    torque = []
    with open(fin) as f:
        for line in f:
            time.append(float(line.split()[0]))
            torque.append(float(line.split()[1]))
    return (time, torque)

def getTorque(path_list):
    data = []
    for ls in path_list:
        fin = os.path.join(ls,"torque.dat")
        (time, torque) = readFile(fin)
        ax.scatter(time,torque, marker='o',label=ls[62:], lw=2)
        t = np.array(torque).mean()
        data.append([ls,t])
    return data


path_list = [#"E:/drum/density/8000/ppsf/0.1/damp/0.1/pwsf/0.4/508mm/12.7mm/0.3J/0.5N",
#              "E:/drum/density/8000/ppsf/0.1/damp/0.1/pwsf/0.4/508mm/12.7mm/0.3J/0.6N",
#              "E:/drum/density/8000/ppsf/0.1/damp/0.1/pwsf/0.4/508mm/12.7mm/0.3J/0.7N",
#              "E:/drum/density/8000/ppsf/0.1/damp/0.1/pwsf/0.4/508mm/12.7mm/0.4J/0.5N",
#              "E:/drum/density/8000/ppsf/0.1/damp/0.1/pwsf/0.4/508mm/12.7mm/0.4J/0.6N",
#              "E:/drum/density/8000/ppsf/0.1/damp/0.1/pwsf/0.4/508mm/12.7mm/0.4J/0.7N",
#              "E:/drum/density/8000/ppsf/0.1/damp/0.1/pwsf/0.4/508mm/12.7mm/0.5J/0.5N",
#              "E:/drum/density/8000/ppsf/0.1/damp/0.1/pwsf/0.4/508mm/12.7mm/0.5J/0.6N",
#              "E:/drum/density/8000/ppsf/0.1/damp/0.1/pwsf/0.4/508mm/12.7mm/0.5J/0.7N",
#              "E:/drum/density/8000/ppsf/0.1/damp/0.1/pwsf/0.4/508mm/19.05mm/0.3J/0.5N",
#              "E:/drum/density/8000/ppsf/0.1/damp/0.1/pwsf/0.4/508mm/19.05mm/0.3J/0.6N",
#              "E:/drum/density/8000/ppsf/0.1/damp/0.1/pwsf/0.4/508mm/19.05mm/0.3J/0.7N",
#              "E:/drum/density/8000/ppsf/0.1/damp/0.1/pwsf/0.4/508mm/19.05mm/0.4J/0.5N",
#              "E:/drum/density/8000/ppsf/0.1/damp/0.1/pwsf/0.4/508mm/19.05mm/0.4J/0.6N",
#              "E:/drum/density/8000/ppsf/0.1/damp/0.1/pwsf/0.4/508mm/19.05mm/0.4J/0.7N",
#              "E:/drum/density/8000/ppsf/0.1/damp/0.1/pwsf/0.4/508mm/19.05mm/0.5J/0.5N",
#              "E:/drum/density/8000/ppsf/0.1/damp/0.1/pwsf/0.4/508mm/19.05mm/0.5J/0.6N",
#              "E:/drum/density/8000/ppsf/0.1/damp/0.1/pwsf/0.4/508mm/19.05mm/0.5J/0.7N",
             "E:/drum/density/8000/ppsf/0.1/damp/0.1/pwsf/0.4/1000mm/25.4mm/0.3J/0.5N",
             "E:/drum/density/8000/ppsf/0.1/damp/0.1/pwsf/0.4/1000mm/25.4mm/0.3J/0.6N",
             "E:/drum/density/8000/ppsf/0.1/damp/0.1/pwsf/0.4/1000mm/25.4mm/0.3J/0.7N",
             "E:/drum/density/8000/ppsf/0.1/damp/0.1/pwsf/0.4/1000mm/25.4mm/0.4J/0.5N",
             "E:/drum/density/8000/ppsf/0.1/damp/0.1/pwsf/0.4/1000mm/25.4mm/0.4J/0.6N",
             "E:/drum/density/8000/ppsf/0.1/damp/0.1/pwsf/0.4/1000mm/25.4mm/0.4J/0.7N",
             "E:/drum/density/8000/ppsf/0.1/damp/0.1/pwsf/0.4/1000mm/25.4mm/0.5J/0.5N",
             "E:/drum/density/8000/ppsf/0.1/damp/0.1/pwsf/0.4/1000mm/25.4mm/0.5J/0.6N",
             "E:/drum/density/8000/ppsf/0.1/damp/0.1/pwsf/0.4/1000mm/25.4mm/0.5J/0.7N"]

fig = plt.figure()
ax = fig.add_axes([0.2,0.2,0.7,0.7])

data = getTorque(path_list)
df = pd.DataFrame(data, columns=['path','torque'])
fout = "../../drum/paper/data/torque1000mm.csv" 
df.to_csv(fout)


    
# path = "../508mm/25.4mm/0.5J/0.6N"
# path = "../../drum/508mm/19.05mm/0.5J/0.5N"
# fin = os.path.join(path,"torque.dat")
# (time1, torque1) = readFile(fin)

# path = "../../drum/508mm/19.05mm/0.5J/0.6N"
# fin = os.path.join(path,"torque.dat")
# (time2, torque2) = readFile(fin)

# path = "../../drum/508mm/19.05mm/0.5J/0.6N"
# fin = os.path.join(path,"torque.dat")
# (time3, torque3) = readFile(fin)



# ax.set_xlim(0,2.0)

# ax.scatter(time1,torque1, marker='o',label="0.5N", lw=2)
# ax.scatter(time2,torque2, marker='o',label="0.6N", lw=2)
# ax.scatter(time3,torque3, marker='o',label="0.7N", lw=2)
 
 
ax.set_ylabel("Torque (Nm)")
ax.set_xlabel("Time (s)")
ax.legend(loc="upper right")

plt.show()

# print(np.array(torque1).mean())
# print(np.array(torque2).mean())
# print(np.array(torque3).mean())
